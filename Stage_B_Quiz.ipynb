# %%
# Import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the data
energy_df= pd.read_csv('energydata_complete.csv')
energy_df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
energy_df.shape
# Out:
# (19735, 29)

# %%
energy_df.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
# checking the missing data
energy_df.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
#drop the 'date' and 'lights' columns
energy_df = energy_df.drop(columns=['date', 'lights'], axis=1)
energy_df
# Out:
#        Appliances         T1       RH_1         T2       RH_2         T3  \
# 0              60  19.890000  47.596667  19.200000  44.790000  19.790000
# 1              60  19.890000  46.693333  19.200000  44.722500  19.790000
# 2              50  19.890000  46.300000  19.200000  44.626667  19.790000
# 3              50  19.890000  46.066667  19.200000  44.590000  19.790000
# 4              60  19.890000  46.333333  19.200000  44.530000  19.790000
# ...           ...        ...        ...        ...        ...        ...
# 19730         100  25.566667  46.560000  25.890000  42.025714  27.200000
# 19731          90  25.500000  46.500000  25.754000  42.080000  27.133333
# 19732         270  25.500000  46.596667  25.628571  42.768571  27.050000
# 19733         420  25.500000  46.990000  25.414000  43.036000  26.890000
# 19734         430  25.500000  46.600000  25.264286  42.971429  26.823333
#
#             RH_3         T4       RH_4         T5  ...         T9     RH_9  \
# ...

# %%
#Normalise the dataset 
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

normalised_energy_df = pd.DataFrame(scaler.fit_transform(energy_df), columns = energy_df.columns)
normalised_energy_df
# Out:
#        Appliances        T1      RH_1        T2      RH_2        T3      RH_3  \
# 0        0.046729  0.327350  0.566187  0.225345  0.684038  0.215188  0.746066
# 1        0.046729  0.327350  0.541326  0.225345  0.682140  0.215188  0.748871
# 2        0.037383  0.327350  0.530502  0.225345  0.679445  0.215188  0.755569
# 3        0.037383  0.327350  0.524080  0.225345  0.678414  0.215188  0.758685
# 4        0.046729  0.327350  0.531419  0.225345  0.676727  0.215188  0.758685
# ...           ...       ...       ...       ...       ...       ...       ...
# 19730    0.084112  0.926786  0.537657  0.711655  0.606309  0.830841  0.579374
# 19731    0.074766  0.919747  0.536006  0.701769  0.607836  0.825302  0.582178
# 19732    0.242991  0.919747  0.538666  0.692651  0.627198  0.818378  0.603988
# 19733    0.383178  0.919747  0.549491  0.677054  0.634717  0.805085  0.585294
# 19734    0.392523  0.919747  0.538758  0.666171  0.632902  0.799546  0.579062
#
# ...

# %%
# spliting the Dataset

X = normalised_energy_df.drop(['Appliances'], axis = 1)
y = normalised_energy_df['Appliances']

# %%
# training & testing spliting the  data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

print('X_train shape: {}'.format(X_train.shape))
print('X_test shape: {}'.format(X_test.shape))
print('y_train shape: {}'.format(y_train.shape))
print('y_test shape: {}'.format(y_test.shape))
# Out:
# X_train shape: (13814, 26)
# X_test shape: (5921, 26)
# y_train shape: (13814,)
# y_test shape: (5921,)

# %%
# choose sample from dataset
reg_energy_df = normalised_energy_df[['T2', 'T6']]
reg_energy_df.head()
# Out:
#          T2        T6
# 0  0.225345  0.381070
# 1  0.225345  0.375443
# 2  0.225345  0.367487
# 3  0.225345  0.363800
# 4  0.225345  0.361859

# %%
# Reshape the sample of dataset
xa = reg_energy_df['T2'].values.reshape(-1,1)
ya = reg_energy_df['T6'].values.reshape(-1,1)

# %%
# training & testing spliting sample of data
xa_train, xa_test, ya_train, ya_test = train_test_split(xa, ya, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()

# fiting the model to training dataset
linear_model.fit(xa_train, ya_train)

# for predictions
predicted_values = linear_model.predict(xa_test)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train, y_train)
y_pred = reg.predict(X_test)
train_score = reg.score(X_train, y_train)
test_score = reg.score(X_test, y_test)
print('Training score: {:.3f}'.format(train_score))
print('Testing score: {:.3f}'.format(test_score))
# Out:
# Training score: 0.145
# Testing score: 0.149

# %% [markdown]
# **What is the R^2 value in two d.p**

# %%
from sklearn.metrics import r2_score
r2_scor = r2_score(ya_test, predicted_values)
print('R-squared value in two d.p.:', round(r2_scor, 2))
# Out:
# R-squared value in two d.p.: 0.64

# %% [markdown]
# **Mean Absolute Error (MAE)**

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
print('Mean Absolute Error: {}'.format(round(mae, 2)))
# Out:
# Mean Absolute Error: 0.05

# %% [markdown]
# **Residual Sum of Squares(RSS)**

# %%
rss = np.sum(np.square(y_test - y_pred))
print('Residual Sum of Squares(RSS):', round(rss, 2))
# Out:
# Residual Sum of Squares(RSS): 45.35

# %%
# Root Mean Squared Error (RMSE)
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print('Root Mean Squared Error: {}'.format(round(rmse, 3)))
# Out:
# Root Mean Squared Error: 0.088

# %% [markdown]
# **coefficient of determination**

# %%
#from sklearn.metrics import r2_score
r_squared = r2_score(y_test, y_pred)
print('Coefficient of Determination : {}'.format(round(r_squared, 2)))
# Out:
# Coefficient of Determination : 0.15

# %% [markdown]
# **Which features have the lowest and highest weights respectively**

# %%
def get_weights_df(model, feat, col_name):
    
  #this function returns the weight of every feature
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features', col_name]
    weights_df[col_name].round(3)
    
    return weights_df

# %% [markdown]
# **Which features have the lowest and highest weights respectively**

# %%
linear_reg_weights = get_weights_df(reg, X_train, 'Linear_model_Weight')
linear_reg_weights
# Out:
#        Features  Linear_model_Weight
# 0           rv1        -1.199400e+11
# 1          RH_2        -4.569467e-01
# 2         T_out        -3.219377e-01
# 3            T2        -2.363617e-01
# 4            T9        -1.899346e-01
# 5          RH_8        -1.576305e-01
# 6        RH_out        -7.769361e-02
# 7          RH_7        -4.455710e-02
# 8          RH_9        -3.981882e-02
# 9            T5        -1.564789e-02
# 10           T1        -3.281051e-03
# 11  Press_mm_hg         6.874983e-03
# 12           T7         1.030306e-02
# 13   Visibility         1.228827e-02
# 14         RH_5         1.603044e-02
# 15         RH_4         2.639802e-02
# 16           T4         2.898319e-02
# 17    Windspeed         2.919986e-02
# 18         RH_6         3.807195e-02
# 19         RH_3         9.609626e-02
# 20           T8         1.020212e-01
# 21    Tdewpoint         1.178136e-01
# 22           T6         2.364848e-01
# 23           T3         2.907524e-01
# ...

# %% [markdown]
# RH_2 feature has the lowest weight, and RH_1 feature has the highest weight

# %% [markdown]
# **Ridge regression model alpha value 0.4.**
# **Is there any change to the root mean squared error (RMSE)**

# %%
from sklearn.linear_model import Ridge

ridge_reg = Ridge(alpha=0.4)
ridge_reg.fit(X_train, y_train)

#obtain predictions
ridge_pred = ridge_reg.predict(X_test)

print("Training set score: {:.3f}".format(ridge_reg.score(X_train, y_train)))
print("Test set score: {:.3f}".format(ridge_reg.score(X_test, y_test)))
# Out:
# Training set score: 0.145
# Test set score: 0.149

# %%
#root mean squared error
from sklearn.metrics import  mean_squared_error

rmse = np.sqrt(mean_squared_error(y_test, ridge_pred))
print('RMSE:',(round(rmse, 3)))
# Out:
# RMSE: 0.088

# %% [markdown]
# No change in root meas squared error, rmse for the linear model is also 0.088

# %% [markdown]
# **Lasso regression model with an alpha value of 0.001**
# **How many of the features have non-zero feature weights?**

# %%
from sklearn.linear_model import Lasso

lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(X_train, y_train)

#obtain predictions
lasso_pred = lasso_reg.predict(X_test)

print("Training set score: {:.3f}".format(lasso_reg.score(X_train, y_train)))
print("Test set score: {:.3f}".format(lasso_reg.score(X_test, y_test)))
# Out:
# Training set score: 0.025
# Test set score: 0.027

# %%
#Lasso regression weights
lasso_weights_df = get_weights_df(lasso_reg, X_train, 'Lasso_weight')
lasso_weights_df
# Out:
#        Features  Lasso_weight
# 0        RH_out     -0.049557
# 1          RH_8     -0.000110
# 2            T1      0.000000
# 3     Tdewpoint      0.000000
# 4    Visibility      0.000000
# 5   Press_mm_hg     -0.000000
# 6         T_out      0.000000
# 7          RH_9     -0.000000
# 8            T9     -0.000000
# 9            T8      0.000000
# 10         RH_7     -0.000000
# 11          rv1     -0.000000
# 12           T7     -0.000000
# 13           T6      0.000000
# 14         RH_5      0.000000
# 15           T5     -0.000000
# 16         RH_4      0.000000
# 17           T4     -0.000000
# 18         RH_3      0.000000
# 19           T3      0.000000
# 20         RH_2     -0.000000
# 21           T2      0.000000
# 22         RH_6     -0.000000
# 23          rv2     -0.000000
# 24    Windspeed      0.002912
# 25         RH_1      0.017880

# %% [markdown]
# A total of four (4) features have non- zero weights. They are RH_out, RH_8, Windspeed and RH_1

# %% [markdown]
# **New RMSE with the lasso regression?**

# %%
from sklearn.metrics import  mean_squared_error

rmse = np.sqrt(mean_squared_error(y_test, lasso_pred))
print('RMSE:',(round(rmse, 3)))
# Out:
# RMSE: 0.094
